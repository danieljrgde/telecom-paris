# %% [markdown]
# # TP1: Non-Parametric Regression by Cubic Splines
#
# *By Daniel Deutsch*

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
# Matplotlib styles
plt.style.use('ggplot')
plt.rcParams.update({
    'figure.figsize': (15, 4),
    'axes.prop_cycle': plt.cycler(color=["#4C72B0", "#C44E52", "#55A868", "#8172B2", "#CCB974", "#64B5CD"]),
    'axes.facecolor': "#EAEAF2"
})

# %% [markdown]
# # Preliminary Exercises
#
# ### Preliminary Exercise 1
#
# ### Preliminary Exercise 2
#
# ### Preliminary Exercise 3
#
# ### Preliminary Exercise 4
#
# ### Preliminary Exercise 5

# %% [markdown]
# # Exercise 1

# %%
# Loads the data (only uses the columns regarding time and acceleration)
df = pd.read_csv("./datasets/motorcycle_data.txt", names=['id', 't', 'a'], usecols=['t', 'a'], sep="\s+")

# Obtains the arrays y and t
y = df['a'].values
t = df['t'].values

# Plots the obtained data
plt.plot(t, y)
plt.title("Acceleration x Time")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.show()
