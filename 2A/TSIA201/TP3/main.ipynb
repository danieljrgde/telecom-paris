#  7;33;40  7;33;41  7;33;42  7;33;43  7;33;44  7;33;45  7;33;46  7;33;47
#  7;34;40  7;34;41  7;34;42  7;34;43  7;34;44  7;34;45  7;34;46  7;34;47
#  7;35;40  7;35;41  7;35;42  7;35;43  7;35;44  7;35;45  7;35;46  7;35;47
#  7;36;40  7;36;41  7;36;42  7;36;43  7;36;44  7;36;45  7;36;46  7;36;47
#  7;37;40  7;37;41  7;37;42  7;37;43  7;37;44  7;37;45  7;37;46  7;37;47

# %%
class Base:

    def __init__(self, name, tdata=None, freq=None, mag=None):

        if not ((tdata is None) ^ (freq is None or mag is None)):
            raise Exception("You must provide a tdata or a freq and mag arrays")
        if not(freq is None or mag is None):
            if len(freq) != len(mag):
                raise Exception("freq and mag arrays must be of the same length")
        
        self.name = name

        # Time domain attributes
        if not(tdata is None):
            self.tdata = np.asarray(tdata)
        else:
            self.tdata = np.fft.ifft(mag)

        # Frequency domain attributes
        if not(freq is None or mag is None):
            self.freq = np.asarray(freq)
            self.mag = np.asarray(mag)
        else:
            len_fft = 4096                                                           # Length of the transformed axis of the output
            self.freq, self.mag = sig.freqz(self.tdata, worN=len_fft, whole=True)    # Obtains the frequency and magnitude
            self.freq = self.freq/(2*np.pi)                                          # Converts the frequency to (rad/sample)/2π

    
    #------------------------------#
    #--- SAMPLES ------------------#
    #------------------------------#

    def step_split_sample(self, step):
        tdatas = [self.tdata[i::step] for i in range(step)]
        max_len = max([len(tdata) for tdata in tdatas])
        for i, tdata in enumerate(tdatas):
            if len(tdata) != max_len:
                tdatas[i] = np.append(tdata, 0)
            tdatas[i] = self.__class__(f"{self.name}{i}", tdatas[i])
        return tuple(tdatas) 


    #------------------------------#
    #--- PLOTS --------------------#
    #------------------------------#
    
    def data_plot(self, discrete=False, absolute=False, xhighlights=[], yhighlights=[], figsize=(15, 4), save=False):
        
        # Obtain the xaxis
        xaxis = np.abs(self.tdata) if absolute else self.tdata
        
        # Plot
        plt.figure(figsize=figsize)
        plt.title(f"Plot of {self.name}")
        plt.stem(xaxis) if discrete else plt.plot(xaxis)
        plt.xlim(0, len(xaxis)-1)
        plt.ylabel("Amplitude")
        plt.xlabel("Index")
        for xhighlight in xhighlights:
            plt.axvline(x=xhighlight, color="red")
        for yhighlight in yhighlights:
            plt.axhline(y=yhighlight, color="red")
        if save:
            plt.savefig(f"./outputs/figures/{self.name}_data.png", dpi=300, bbox_inches="tight")
        plt.show()


    def spectrogram_plot(self, xhighlights=[], yhighlights=[], figsize=(15, 4), save=False):
        
        # Obtain the spectrogram params
        f, t, Sxx = sig.spectrogram(self.tdata, self.freq)

        # Plot
        plt.figure(figsize=figsize)
        plt.title(f"Spectogram of {self.name}")
        plt.pcolormesh(t, f, 20*np.log10(Sxx), shading="auto")
        plt.ylabel("Frequency [Hz]")
        plt.xlabel("Time [s]")
        for xhighlight in xhighlights:
            plt.axvline(x=xhighlight, color="red")
        for yhighlight in yhighlights:
            plt.axhline(y=yhighlight, color="red")
        if save:
            plt.savefig(f"./outputs/figures/{self.name}_spectrogram.png", dpi=300, bbox_inches="tight")
        plt.show()


    def freqz_plot(self, whole=False, absolute=True, db=True, xhighlights=[], yhighlights=[], figsize=(15, 4), save=False):

        # Frequency
        freq = self.freq

        # Magnitude
        mag = np.abs(self.mag) if absolute else self.mag
        mag = 20*np.log10(mag) if db else mag
        mag[np.abs(mag-np.mean(mag)) > 2*np.std(mag)] = np.nan   # Remove outliers for the plot

        if not whole:
            mag = mag[:int(len(mag)/2)]
            freq = freq[:int(len(freq)/2)]
        
        # Plot
        plt.figure(figsize=figsize)
        plt.title(f"Frequency response of {self.name}")
        plt.plot(freq, mag)
        plt.xlim(freq[0], freq[-1])
        plt.ylabel("Magnitude [dB]") if db else plt.ylabel("Magnitude")
        plt.xlabel("Frequency [(rad/sample)/2π]")
        for xhighlight in xhighlights:
            plt.axvline(x=xhighlight, color="red")
        for yhighlight in yhighlights:
            plt.axhline(y=yhighlight, color="red")
        if save:
            plt.savefig(f"./outputs/figures/{self.name}_freqz.png", dpi=300, bbox_inches="tight")
        plt.show()

# %%
class Signal(Base):

    def __init__(self, name, tdata=None, freq=None, mag=None, fs=None, file=None):
        if not ((tdata is None) ^ (file == None)):
            raise Exception("You must provide a tdata or a .wav file")
        if file:
            fs, tdata = wavfile.read(file)
        self.fs = int(fs) if fs else fs
        Base.__init__(self, name, tdata)


    #------------------------------#
    #--- SHIFTING -----------------#
    #------------------------------#

    def shift(self, name, power_of_z):
        tdata = self.tdata
        tdata = np.append(tdata[power_of_z:], power_of_z*[0]) if power_of_z > 0 else np.append(abs(power_of_z)*[0], tdata[:power_of_z])
        return self.__class__(name, tdata=tdata, fs=self.fs)


    #------------------------------#
    #--- SAMPLING -----------------#
    #------------------------------#

    def under_sample(self, name, M):
        tdatas = self.step_split_sample(M)
        if self.fs:
            return self.__class__(name=name, tdata=tdatas[0].tdata, fs=self.fs/M)
        else:
            return self.__class__(name=name, tdata=tdatas[0].tdata)
        

    def over_sample(self, name, L):
        tdata = np.insert(self.tdata, range(1, len(self.tdata)+1)[::L-1], 0)
        if self.fs:
            return self.__class__(name=name, tdata=tdata, fs=self.fs*L) 
        else:
            return self.__class__(name=name, tdata=tdata) 

    #------------------------------#
    #--- PLOT ---------------------#
    #------------------------------#

    def time_plot(self, absolute=False, xhighlights=[], yhighlights=[], figsize=(15, 4), save=False):

        # Obtains the time axis
        t = np.linspace(0, len(self.tdata)/self.fs, len(self.tdata))

        # Plot
        plt.figure(figsize=figsize)
        plt.title(f"Time plot of {self.name}")
        plt.plot(t, np.abs(self.tdata)) if absolute else plt.plot(t, self.tdata)            
        plt.xlim(t[0], t[-1])
        plt.ylabel("Amplitude")
        plt.xlabel("Time [s]")
        for xhighlight in xhighlights:
            plt.axvline(x=xhighlight, color="red")
        for yhighlight in yhighlights:
            plt.hlines(y=yhighlight, color="red")
        if save:
            plt.savefig(f"./outputs/figures/{self.name}_time.png", dpi=300, bbox_inches="tight")
        plt.show()
            

    #------------------------------#
    #--- LISTEN -------------------#
    #------------------------------#

    def listen(self):
        
        # Saves the .wav
        if not self.fs:
            raise Exception("the sample freq (sample/sec) must be provided")
        wavfile.write(f"./outputs/sounds/{self.name}.wav", self.fs, np.asarray(self.tdata, dtype=np.int16))

        # Uses pyaudio to play the signal
        chunk = 1024
        pa = pyaudio.PyAudio()
        audio = wave.open(f"./outputs/sounds/{self.name}.wav", "rb")
        stream = pa.open(
            format = pa.get_format_from_width(audio.getsampwidth()),
            channels = audio.getnchannels(),
            rate = audio.getframerate(),
            output = True
        )
        data = audio.readframes(chunk)
        while data:
            stream.write(data)
            data = audio.readframes(chunk)
        stream.stop_stream()
        stream.close()
        pa.terminate()

# %%
class Filter(Base):

    def apply(self, name, signal):
        conv = np.convolve(self.tdata, signal.tdata)
        return Signal(name, tdata=conv, fs=signal.fs)

# %% [markdown]
# # 1.1

# %%
def cqf_analysis_filterbank(x, h0):
    N = h0.tdata.size
    signal = (-1.0)**(np.arange(N))
    h1=h0.tdata[::-1]*signal
    h1 = Filter("h1", tdata=h1)
    
    xx = np.zeros(len(x.tdata) + len(h0.tdata) - 1)

    xx[0:len(x.tdata)] = x.tdata

    x0 = Signal("x0", tdata=sig.lfilter(h0.tdata,[1],xx))
    x1 = Signal("x1", tdata=sig.lfilter(h1.tdata,[1],xx))


    v0 = x0.under_sample("v0", 2)
    v1 = x1.under_sample("v1", 2)
    
    return [v0, v1]

# %% [markdown]
# # 1.2

# %%
def cqf_synthesis_filterbank(v0, v1, h0):
    N = h0.tdata.size
    signal = (-1.0)**(np.arange(N))
    h1=h0.tdata[::-1]*signal
    h1 = Filter("h1", tdata=h1)
    f0 = h0.tdata[::-1]
    f1 = h1.tdata[::-1]
    f0 = Filter("f0", tdata=f0) 
    f1 = Filter("f1", tdata=f1)
    u0 = v0.over_sample("u0", 2)
    u1 = v1.over_sample("u1", 2)
    y0 = Signal("y0", tdata=sig.lfilter(f0.tdata,[1],u0.tdata))
    y1 = Signal("y1", tdata=sig.lfilter(f1.tdata,[1],u1.tdata))
    y = Signal("y", tdata=y0.tdata + y1.tdata)
    return y

# %% [markdown]
# # 1.3

# %%
x=np.zeros(512)
N1 = 100
N2 = 200
N3 = 300
N4 = 380
N5 = 512
r1 = np.arange(0,N1)
r2 = np.arange(N1,N2)
r3 = np.arange(N2,N3)
r4 = np.arange(N3,N4)
r5 = np.arange(N4,N5)
x[r1] = r1/float(N1)
x[r2] =0.5+ ((r2-float(N1))/float(N2))**2
x[r3] = x[N2-1]
t4 = (r4-float(N3))/float(N4)
x[r4] = -80*t4**3 + 20*t4**2 + x[N2-1]
x[r5] = 0.5*(1-(r5-float(N4))/(float(N5-N4)))
x[420:423] =1
plt.plot(x)
plt.title("Piecewise polynomial signal")
plt.show()

# %%
# First defining h0 as the Haar filter
h0 = np.zeros(2)
h0[0] = 0.707106781187
h0[1] = 0.707106781187
h0 = Filter("h0", tdata=h0)

x_haar = Signal("x_haar", tdata=x)

v0, v1 = cqf_analysis_filterbank(x_haar,h0)
y_haar = cqf_synthesis_filterbank(v0,v1,h0)
plt.plot(y_haar.tdata, color="red")
plt.plot(x, color="blue")
plt.legend(["Reconstructed", "Original"])
plt.title("Reconstructed signal vs Original signal")
plt.show()
print("Relative error: {}".format(np.linalg.norm(x-y_haar.tdata[h0.tdata.size-1:x.size+h0.tdata.size-1])/np.linalg.norm(x)))
# Out:
# Relative error: 1.2797703641191922e-12

# %%
# First defining h0 as the Daubechies filter
h0 = np.zeros(4)
h0[0] = 0.482962913145
h0[1] = 0.836516303738
h0[2] = 0.224143868042
h0[3] = -0.129409522551

h0 = Filter("h0", tdata=h0)

x_daubechies = Signal("x_daubechies", tdata=x)

v0, v1 = cqf_analysis_filterbank(x_daubechies,h0)
y_daubechies = cqf_synthesis_filterbank(v0,v1,h0)
plt.plot(y_daubechies.tdata, color="red")
plt.plot(x, color="blue")
plt.legend(["Reconstructed", "Original"])
plt.title("Reconstructed signal vs Original signal")
plt.show()
print("Relative error: {}".format(np.linalg.norm(x-y_daubechies.tdata[h0.tdata.size-1:x.size+h0.tdata.size-1])/np.linalg.norm(x)))
# Out:
# Relative error: 1.2770113573497566e-12

# %% [markdown]
# # 1.4

# %% [markdown]
# Yes, we achieve perfect reconstruction, what can be comproved by the relative error displayed above.

# %% [markdown]
# # 1.5

# %%
print("For the Haar Filter, printing the last M-1 values and the last zero")
print()
print(y_haar.tdata[x.size:])
print()
print("For the Daubechies Filter, printing the last M-1 values and the last zero")
print()
print(y_daubechies.tdata[x.size:])
# Out:
# For the Haar Filter, printing the last M-1 values and the last zero
#
# [0.00378788 0.        ]
#
# For the Daubechies Filter, printing the last M-1 values and the last zero
#
# [1.13636364e-02 7.57575758e-03 3.78787879e-03 2.20396618e-15]

# %% [markdown]
# We can see that terms that were zero at the zero padded original signal, are now different from zero. The last element of the reconstructed signal will be zero because of our filterbank implementation.
#
# For Haar Filter (with size 2), 1 coefficient is introduced.
# For Daubechies Filter (with size 4), 3 coefficients are introduced.

# %% [markdown]
# # 1.6

# %%
def cqf_analysis_filterbank_periodisation(x, h0):
    N = h0.tdata.size
    signal = (-1.0)**(np.arange(N))
    h1=h0.tdata[::-1]*signal
    h1 = Filter("h1", tdata=h1)
    xx = np.zeros(len(x.tdata) + len(h0.tdata) - 1)

    xx[0:len(x.tdata)] = x.tdata
    x_per = np.concatenate([xx]*3, axis=0)

    x0 = Signal("x0", tdata=sig.lfilter(h0.tdata,[1],x_per))
    x1 = Signal("x1", tdata=sig.lfilter(h1.tdata,[1],x_per))


    v0 = x0.under_sample("v0", 2)
    v1 = x1.under_sample("v1", 2)
    
    return (v0, v1)

def cqf_synthesis_filterbank_periodisation(v0, v1, h0):
    N = h0.tdata.size
    signal = (-1.0)**(np.arange(N))
    h1=h0.tdata[::-1]*signal
    h1 = Filter("h1", tdata=h1)
    f0 = h0.tdata[::-1]
    f1 = h1.tdata[::-1]
    f0 = Filter("f0", tdata=f0) 
    f1 = Filter("f1", tdata=f1)
    u0 = v0.over_sample("u0", 2)
    u1 = v1.over_sample("u1", 2)
    y0 = Signal("y0", tdata=sig.lfilter(f0.tdata,[1],u0.tdata))
    y1 = Signal("y1", tdata=sig.lfilter(f1.tdata,[1],u1.tdata))
    y = Signal("y", tdata=y0.tdata + y1.tdata)
    return Signal("y",tdata=y.tdata[len(y.tdata)//3:2*len(y.tdata)//3])

# %%
h0 = np.zeros(2)
h0[0] = 0.707106781187
h0[1] = 0.707106781187

h0 = Filter("h0", tdata=h0)

x_haar = Signal("x_haar", tdata=x)

v0, v1 = cqf_analysis_filterbank_periodisation(x_daubechies,h0)
y_haar = cqf_synthesis_filterbank_periodisation(v0,v1,h0)
print(y_haar.tdata.size)
plt.plot(y_haar.tdata, color="red")
plt.plot(x, color="blue")
plt.legend(["Reconstructed", "Original"])
plt.title("Reconstructed signal vs Original signal")
plt.show()
print(x.size)
print("Relative error: {}".format(np.linalg.norm(x-y_daubechies.tdata[h0.tdata.size-1:x.size+h0.tdata.size-1])/np.linalg.norm(x)))
# Out:
# 513
# 512
# Relative error: 0.1144044175726436

# %%
h0 = np.zeros(4)
h0[0] = 0.482962913145
h0[1] = 0.836516303738
h0[2] = 0.224143868042
h0[3] = -0.129409522551

h0 = Filter("h0", tdata=h0)

x_daubechies = Signal("x_daubechies", tdata=x)

v0, v1 = cqf_analysis_filterbank_periodisation(x_daubechies,h0)
y_daubechies = cqf_synthesis_filterbank_periodisation(v0,v1,h0)
print(y_daubechies.tdata.size)
plt.plot(y_daubechies.tdata, color="red")
plt.plot(x, color="blue")
plt.legend(["Reconstructed", "Original"])
plt.title("Reconstructed signal vs Original signal")
plt.show()
print(x.size)
print("Relative error: {}".format(np.linalg.norm(x-y_daubechies.tdata[h0.tdata.size-1:x.size+h0.tdata.size-1])/np.linalg.norm(x)))
# Out:
# 515
# 512
# Relative error: 1.277001766605939e-12

# %%
print("For the Haar Filter, printing the last M-1 values and the last zero")
print()
print(y_haar.tdata[x.size:])
print()
print("For the Daubechies Filter, printing the last M-1 values and the last zero")
print()
print(y_daubechies.tdata[x.size:])
# Out:
# For the Haar Filter, printing the last M-1 values and the last zero
#
# [0.00378788]
#
# For the Daubechies Filter, printing the last M-1 values and the last zero
#
# [0.01136364 0.00757576 0.00378788]

# %% [markdown]
# We can observe that we are still having coefficient expansion despite the use of periodization. This was a confusion point for the group (we tried contacting Marco Cagnazzo via email but we had no response since 23/10).

# %% [markdown]
# # 1.7

# %% [markdown]
# We will use the Dubechies Filter

# %%
def MRA(x, h0, nLev):
    
    u0, u1 = cqf_analysis_filterbank(x, h0)
    
    if (nLev==0):
        return x
    
    return (MRA(u0, h0, nLev-1), u1)

values = MRA(x_daubechies,h0,5)

# %%
plt.plot(values[0][0][0][0][0].tdata)
plt.title('Continuous component of input signal for 5 levels of wavelet decomposition')
plt.show()

# %% [markdown]
# # 1.8
#
# By producing several levels of the DWT using the analysis filter bank, we can observe that the highest frequencies are being lost on the final result.
#
# To analyse the coefficient expansion (in the case where nLev = 5) on the final result, let us observe the last (4-1) values of the coefficient array. We used 4-1 as the size of Daubechies Filter is 4 and the number of padded zeros at the beggining is, therefore, 4-1 = 3.

# %%
print(values[0][0][0][0][0].tdata[-3:])
# Out:
# [ 0.42137218 -0.02552349  0.001366  ]

# %% [markdown]
# We conclude that there exists a coefficient expansion (also given that we are not using the periodized CQF Analysis function).
#
# The discontinuities in the original signal indicate zones with high frequency. As stated above, the production of several levels of the DWT using the analysis filter bank causes the lost of high frequencies. Therefore, the discontinuities once observed in the original signal and in the lower DWT levels are now spreaded and not well observable on DWT with higher nLev.

# %% [markdown]
# # 1.9 and 1.10

# %%
def compare_freqz(*args, **kwargs):

    plt.figure(figsize=(15, 4))
    plt.title(f"Frequency response of " + ", ".join([arg.name for arg in args]))

    for arg in args:
    
        # Obtains the arrays of magnitude and frequency of the filter
        len_fft = 4096                                   # Length of the transformed axis of the output
        freq, mag = sig.freqz(arg.tdata, worN=len_fft)   # Obtains the frequency and magnitude

        # Frequency
        freq = freq/(2*np.pi)   # Converts the frequency to (rad/sample)/2π
        mag = np.abs(mag)       # Gets the absolute value of the magnitude
    
        # Plot
        plt.plot(freq, mag)

    plt.legend([arg.name for arg in args])
    plt.ylabel("Magnitude")
    plt.xlabel("Frequency [(rad/sample)/2π]")
    plt.show() 

# 1 vanishing moment
h0_1 = Filter("h0_1", tdata=pywt.Wavelet("db1").dec_lo)   # Low-pass
h1_1 = Filter("h1_1", tdata=pywt.Wavelet("db1").dec_hi)   # High-pass

# 2 vanishing moments
h0_2 = Filter("h0_2", tdata=pywt.Wavelet("db2").dec_lo)   # Low-pass
h1_2 = Filter("h1_2", tdata=pywt.Wavelet("db2").dec_hi)   # High-pass

# 3 vanishing moments
h0_3 = Filter("h0_3", tdata=pywt.Wavelet("db3").dec_lo)   # Low-pass
h1_3 = Filter("h1_3", tdata=pywt.Wavelet("db3").dec_hi)   # High-pass

# 4 vanishing moments
h0_4 = Filter("h0_4", tdata=pywt.Wavelet("db4").dec_lo)   # Low-pass
h1_4 = Filter("h1_4", tdata=pywt.Wavelet("db4").dec_hi)   # High-pass

compare_freqz(h0_1, h1_1, h0_2, h1_2, h0_3, h1_3, h0_4, h1_4)

# %% [markdown]
# By the plots shown above, it is clear that the filters with higher vanishing moments are the ones with the flatter frequency response at $\omega = \pi$ .

# %% [markdown]
# # 2.1

# %%
img = mpimg.imread("./inputs/lena.jpg")
plt.imshow(img)
plt.set_cmap("gray")
plt.show()

# %% [markdown]
# # 2.2

# %%
NLEV = 1

filter_bank = pywt.Wavelet("db3")
coeffs = pywt.wavedec2(img, filter_bank, mode="per", level=NLEV)
arr1 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, "Scaled DWT coeffs")

plt.figure()
plt.imshow(np.abs(arr1/arr1.max()))
plt.set_cmap("jet")
plt.title("Unscaled DWT coefficients")
plt.show()

decoded = pywt.waverec2(coeffs, filter_bank, mode="per")

plt.imshow(np.uint8(decoded))
plt.title("Inverse DWT")
plt.set_cmap("gray")
plt.show()

# %%
NLEV = 2

filter_bank = pywt.Wavelet("db3")
coeffs = pywt.wavedec2(img, filter_bank, mode="per", level=NLEV)
arr2 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, "Scaled DWT coeffs")

plt.figure()
plt.imshow(np.abs(arr2/arr2.max()))
plt.set_cmap("jet")
plt.title("Unscaled DWT coefficients")
plt.show()

decoded = pywt.waverec2(coeffs, filter_bank, mode="per")

plt.imshow(np.uint8(decoded))
plt.title("Inverse DWT")
plt.set_cmap("gray")
plt.show()

# %%
plt.title(f"Subband histogram with NLEV = 1")
plt.hist(arr1)
plt.show()
plt.title(f"Subband histogram with NLEV = 2")
plt.hist(arr2)
plt.show()

# %% [markdown]
# Performing the 2D DWT of the lenna image on one level and then on two levels, we obtain a final version generated by taking the down-scale version of the image from the space domain to the wavelet domain. In this order, we are taking the most important bits in the horizontal and vertical direction of the original image. Since we are using a 2D decomposition we have more details compared with the 1D DWT, as we can see in the diagonal equivalent, we have more black coefficients in 2D compared with 1D.
#
# The sub band histogram shows us the number of pixels in the gray scale range. Since lena is a gray scale image, we will see the frequency of the black and white coefficients in the image. We analyze the coefficients with most details, in this case the flat regions would correspond to the gray sections (less detailed) of lenna image.  Analyzing the first histogram it is noticed that most of the wavelet coefficients have near-zero values because it corresponded to flat regions in the image. Also, the black and white coefficients fill only a small range of the values in the histogram. When we increase the level of the DWT, the coefficients will start to move to the sides in order that the black and white coefficients are increasing. Therefore, we can see that the concentration near 0 is more intense with greater NLEVs
#
# As we compress the image the near-zero values start decreasing. This is the reason because we are eliminating the flat regions of the image with the idea of get the pixels with the highest gradient (details).

# %% [markdown]
# # 2.3

# %%
NLEV = 1

filter_bank = pywt.Wavelet("bior4.4")
coeffs = pywt.wavedec2(img, filter_bank, mode="per", level=NLEV)
arr2 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, "Scaled DWT coeffs")

plt.figure()
plt.imshow(np.abs(arr2/arr2.max()))
plt.set_cmap("jet")
plt.title("Unscaled DWT coefficients")
plt.show()

decoded = pywt.waverec2(coeffs, filter_bank, mode="per")

plt.imshow(np.uint8(decoded))
plt.title("Inverse DWT")
plt.set_cmap("gray")
plt.show()

# %%
NLEV = 2

filter_bank = pywt.Wavelet("bior4.4")
coeffs = pywt.wavedec2(img, filter_bank, mode="per", level=NLEV)
arr2 = wtt.coeffs_to_array(coeffs)
wtt.wtView(coeffs, "Scaled DWT coeffs")

plt.figure()
plt.imshow(np.abs(arr2/arr2.max()))
plt.set_cmap("jet")
plt.title("Unscaled DWT coefficients")
plt.show()

decoded = pywt.waverec2(coeffs, filter_bank, mode="per")

plt.imshow(np.uint8(decoded))
plt.title("Inverse DWT")
plt.set_cmap("gray")
plt.show()

# %%
plt.title(f"Subband histogram with NLEV = 1")
plt.hist(arr1)
plt.show()
plt.title(f"Subband histogram with NLEV = 2")
plt.hist(arr2)
plt.show()

# %% [markdown]
# Since the DWT is a linear operator, we assume that the noise in the image is a random process, we will see that in term of the coefficients the final result of the image will be:
#
# $$C_j^r[k]= C_j^s[k]+C_j^n[k]$$
#
# With r equal to the result image, s the signal coefficients and n the noise coefficients.
#
# Since we are using the linear-phase filters at the end we are removing the outlines of the Lenna image. In other words, we are taking part of the noise coefficients that are the details observed in the sub bands. This is the reason why the 2D DWT in a denoised image shows us less details in the coefficients so it is noticed that most of the wavelet coefficients have near-zero values because it corresponded to flat regions in the image.
#
# To apply a linear-phase filters and the DWT operator it is necessary to use a method that keeps the outlines and removes the noise that is not
# our interest. For this purpose, we can use segmentation like thresholding to create binary images.

# %% [markdown]
# # 2.4 and 2.5

# %%
h0 = Filter("h0", tdata=pywt.Wavelet("bior4.4").dec_lo)
h1 = Filter("h1", tdata=pywt.Wavelet("bior4.4").dec_hi)
h0.freqz_plot(db=False)
h1.freqz_plot(db=False)

# %% [markdown]
# # 2.6

# %%
pywt.wavedec2(img,"db1"):

# %% [markdown]
# In respect of the border effects
